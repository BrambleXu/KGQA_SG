# %%
import json
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 提取曹操的简介和图片

# %% [markdown]
# ## 使用request，提取简介

# %% [markdown]
# `html = requests.get(url, headers=headers).content.decode('utf8')`
#
# 上面的一行等于下面的三行，都是把ISO-8859-1解码为utf8。上面的`html`等于下面的`r.text`。这一步就得到了能够传给BeautifulSoup分析的html网页。
#
# ```
# r = requests.get(url, headers=headers)
# r.encoding = r.apparent_encoding
# r.text
# ```

# %%
import requests
url = "https://baike.baidu.com/item/曹操"
headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
                AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.84 Safari/537.36'
        }

r = requests.get(url, headers=headers)
# r.encoding = r.apparent_encoding 
# r.text

print(type(r))
print(r.status_code)
print(r.encoding)
print(r.cookies)
# Out:
# <class 'requests.models.Response'>
# 200
# ISO-8859-1
# <RequestsCookieJar[]>

# %%
import requests
url = "https://baike.baidu.com/item/曹操"
headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
                AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.84 Safari/537.36'
        }

html = requests.get(url, headers=headers).content.decode('utf8')

# %%
soup = BeautifulSoup(html,'lxml')

# %%
# print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="always" name="referrer"/>
#   <meta content="曹操（155年－220年3月15日），字孟德，一名吉利，小字阿瞒，沛国谯县（今安徽亳州）人。东汉末年杰出的政治家、军事家、文学家、书法家，三国中曹魏政权的奠基人。曹操曾担任东汉丞相，后加封魏王，奠定了曹魏立国的基础。去世后谥号为武王。其子曹丕称帝后，追尊为武皇帝，庙号太祖。东汉末年，天下大乱，曹操以汉天子的名义征讨四方，对内消灭二袁、吕布、刘表、马超、韩遂等割据势力，对外降服南匈奴、..." name="description"/>
#   <title>
#    曹操（三国魏政权奠基人）_百度百科
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="//www.baidu.com/img/baidu.svg" mask="" rel="icon" sizes="any"/>
#   <meta content="曹操 魏太祖武皇帝 曹操简史 曹吉利 阿瞒 曹孟德 曹瞒 曹阿瞒 魏武王 魏武 孟德 曹操人物生平 曹操为政举措 曹操历史评价 曹操个人作品 曹操亲属成员 曹操陵寝墓地 曹操轶事典故 曹操影视形象 不黑不吹，曹操的虎豹骑究竟真实水平如何？ 是什么让三国这个人从热血青年变成冷酷枭雄？ 曹操对汉献帝已是仁至义尽，君以草芥待我，我必寇仇报" name="keywords"/>
#   <meta content="https://bkssl.bdimg.com/cms/static/baike.png" name="image"/>
#   <script type="text/javascript">
#    // 配置 PD 监控。
#   window.alogObjectConfig = {
# ...

# %% [markdown]
# 从上面的html中，可以看到简介存储在meta中，content包含简介内容，name="description"表示这一段和简介相关。

# %%
tag = soup.find_all('meta')

# %%
tag
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="always" name="referrer"/>,
#  <meta content="曹操（155年－220年3月15日），字孟德，一名吉利，小字阿瞒，沛国谯县（今安徽亳州）人。东汉末年杰出的政治家、军事家、文学家、书法家，三国中曹魏政权的奠基人。曹操曾担任东汉丞相，后加封魏王，奠定了曹魏立国的基础。去世后谥号为武王。其子曹丕称帝后，追尊为武皇帝，庙号太祖。东汉末年，天下大乱，曹操以汉天子的名义征讨四方，对内消灭二袁、吕布、刘表、马超、韩遂等割据势力，对外降服南匈奴、..." name="description"/>,
#  <meta content="曹操 魏太祖武皇帝 曹操简史 曹吉利 阿瞒 曹孟德 曹瞒 曹阿瞒 魏武王 魏武 孟德 曹操人物生平 曹操为政举措 曹操历史评价 曹操个人作品 曹操亲属成员 曹操陵寝墓地 曹操轶事典故 曹操影视形象 不黑不吹，曹操的虎豹骑究竟真实水平如何？ 是什么让三国这个人从热血青年变成冷酷枭雄？ 曹操对汉献帝已是仁至义尽，君以草芥待我，我必寇仇报" name="keywords"/>,
#  <meta content="https://bkssl.bdimg.com/cms/static/baike.png" name="image"/>,
#  <meta content="" name="csrf-token"/>,
#  <meta content="2018-10-31 16:57:39" itemprop="dateUpdate"/>]

# %% [markdown]
# 得到曹操的简介，存储到字典里

# %%
description = {}
name = '曹操'

for tag in soup.find_all("meta"):
    if tag.get("name", None) == "description":
        print(tag.get("content", None))
        description[name] = tag.get("content", None)
# Out:
# 曹操（155年－220年3月15日），字孟德，一名吉利，小字阿瞒，沛国谯县（今安徽亳州）人。东汉末年杰出的政治家、军事家、文学家、书法家，三国中曹魏政权的奠基人。曹操曾担任东汉丞相，后加封魏王，奠定了曹魏立国的基础。去世后谥号为武王。其子曹丕称帝后，追尊为武皇帝，庙号太祖。东汉末年，天下大乱，曹操以汉天子的名义征讨四方，对内消灭二袁、吕布、刘表、马超、韩遂等割据势力，对外降服南匈奴、...

# %% [markdown]
# 上面的方法遍历了所有的meta，这里我直接找到对应的条目效率会高一些

# %%
metatag = soup.find("meta", {"name": "description"})

# %%
metatag['content']
# Out:
# '曹操（155年－220年3月15日），字孟德，一名吉利，小字阿瞒，沛国谯县（今安徽亳州）人。东汉末年杰出的政治家、军事家、文学家、书法家，三国中曹魏政权的奠基人。曹操曾担任东汉丞相，后加封魏王，奠定了曹魏立国的基础。去世后谥号为武王。其子曹丕称帝后，追尊为武皇帝，庙号太祖。东汉末年，天下大乱，曹操以汉天子的名义征讨四方，对内消灭二袁、吕布、刘表、马超、韩遂等割据势力，对外降服南匈奴、...'

# %% [markdown]
# ## 提取图片
#
# 人物图片所在的位置，div class=side-content, div class=summary-pic, img src=''

# %%
link = soup.find("div", {"class": "summary-pic"}).img['src']
link
# Out:
# 'https://gss1.bdstatic.com/-vo3dSag_xI4khGkpoWK1HF6hhy/baike/w%3D268%3Bg%3D0/sign=25b52880a5efce1bea2bcfcc976a94e3/b21c8701a18b87d69225c069050828381f30fd65.jpg'

# %%
pic = requests.get(link)
path = './images/'
f = open(path + '曹操.jpg', 'wb')
f.write(pic.content)
f.close()
print('Save image')
# Out:
# Save image

# %% [markdown]
# ## 把所有的人物图片都存储到images文件夹内
#
# 先把所有人三国任务做一个list

# %%
def string2list(country):
    """convert name string to name list"""
    country = country.replace("'", '')
    return country.split()

# %%
wei = "'荀攸' '徐晃' '庞德'  '曹操'  '张郃' '荀彧' '司马昭' '曹仁' '曹植' '典韦' '郭嘉' '乐进' '张辽' '夏侯惇' '曹真' '曹爽' '曹纯' '司马炎' '司马懿' '邓艾' '夏侯渊' '贾诩' '许褚' '司马师' '夏侯楙' '蔡瑁' '曹嵩' '邹氏' '程昱' '刘氏' '清河公主' '于禁' '蒯越' '钟会' '文聘' '曹昂'"
shu = "'关兴' '魏延' '诸葛亮' '诸葛瞻' '法正' '黄忠' '关羽' '赵云' '姜维' '张飞' '徐庶' '马良' '诸葛瑾'  '糜芳'  '刘禅' '黄月英' '庞统' '马超' '祝融'  '黄承彦' '沙摩柯' '甘氏' '糜竺' '刘备' '关平' '张苞' '糜氏' '蒋琬' '马谡'"
wu = "'孙坚' '太史慈' '孙策' '大乔' '周泰' '孙权' '黄盖' '周瑜' '甘宁' '吴国太'  '吕蒙' '曹丕' '鲁肃'  '孙尚香' '陆逊' '程普' '徐盛' '孙氏'  '韩当' '张昭' '孙韶' '蒋钦' '凌统' '丁奉' '小乔'"
others = "'袁术' '马腾' '陈宫' '公孙瓒'  '吕布'  '袁绍' '董卓' '孟获' '貂蝉' '吕伯奢' '刘辩' '韩遂' '丁原' '张角' '袁谭' '刘胜' '公孙越' '张梁' '张宝'  '庞德公' '袁熙'  '刘表'  '卢植' '刘协' '王允' '袁尚' '高顺' '张绣' '刘启' '卞氏' '黄祖' '蔡氏'"

# %%
wei = string2list(wei)
shu = string2list(shu)
wu = string2list(wu)
others = string2list(others)

all_people = wei + shu + wu + others 
len(all_people)
# Out:
# 122

# %%
all_people[:10]
# Out:
# ['荀攸', '徐晃', '庞德', '曹操', '张郃', '荀彧', '司马昭', '曹仁', '曹植', '典韦']

# %% [markdown]
# 使用一个for loop来爬去122个武将的图片和简介

# %%
import requests

base_url = "https://baike.baidu.com/item/"

headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
                AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.84 Safari/537.36'
        }


descriptions = {} # save all people descriptions
path = './images/' # save images to this floder

for name in all_people:
    print('Now is %s' % name)
    url = base_url + name
    html = requests.get(url, headers=headers).content.decode('utf8')
    soup = BeautifulSoup(html,'lxml')
    
    
    # 人物简介
    metatag = soup.find("meta", {"name": "description"})
    if metatag:
        descriptions[name] = metatag['content']
    else: # 如果不存在
        descriptions[name] = "暂时没有公开的信息"
        print('%s has no descriptions' % name)
    
    # 图片
    summary = soup.find("div", {"class": "summary-pic"})
    if summary: # 如果存在summary-pic再保存图片
        link = summary.img['src']
        pic = requests.get(link)
        f = open(path + name + '.jpg', 'wb')
        f.write(pic.content)
        f.close()
        print('Save image')
    else:
        print('%s has no picture' % name)
# Out:
# Now is 荀攸
# Save image
# Now is 徐晃
# Save image
# Now is 庞德
# Save image
# Now is 曹操
# Save image
# Now is 张郃
# Save image
# Now is 荀彧
# Save image
# Now is 司马昭
# Save image
# Now is 曹仁
# Save image
# Now is 曹植
# Save image
# Now is 典韦
# Save image
# Now is 郭嘉
# Save image
# Now is 乐进
# Save image
# Now is 张辽
# Save image
# Now is 夏侯惇
# Save image
# Now is 曹真
# Save image
# Now is 曹爽
# Save image
# Now is 曹纯
# Save image
# Now is 司马炎
# Save image
# Now is 司马懿
# Save image
# Now is 邓艾
# Save image
# Now is 夏侯渊
# Save image
# Now is 贾诩
# Save image
# Now is 许褚
# Save image
# Now is 司马师
# Save image
# Now is 夏侯楙
# Save image
# Now is 蔡瑁
# Save image
# Now is 曹嵩
# 曹嵩 has no picture
# Now is 邹氏
# Save image
# Now is 程昱
# Save image
# Now is 刘氏
# 刘氏 has no descriptions
# 刘氏 has no picture
# Now is 清河公主
# Save image
# Now is 于禁
# Save image
# Now is 蒯越
# Save image
# Now is 钟会
# Save image
# Now is 文聘
# Save image
# Now is 曹昂
# Save image
# Now is 关兴
# Save image
# Now is 魏延
# Save image
# ...

# %% [markdown]
# 曹嵩找不到图片，有些人物没有图片

# %%
url = "https://baike.baidu.com/item/曹嵩"
html = requests.get(url, headers=headers).content.decode('utf8')
soup = BeautifulSoup(html,'lxml')

# %%
link = soup.find("div", {"class": "summary-pic"})

# %%
link is None
# Out:
# True

# %% [markdown]
# ## 检查爬取的结果
#
# * 没有介绍的人：刘氏
# * 没有图片的人：曹嵩，刘氏，庞德公，黄祖
#
# 其中刘氏在百度百科中应该是刘夫人（曹操的妻妾）。如果默认爬取同名的第一个人，返回的是袁绍的妻子。应该这种名字不怎么特殊，以防万一检查一下其他几个女性的介绍

# %%
print(descriptions['卞氏'] + "\n") # 曹操妻子，曹丕母亲
print(descriptions['刘氏'] + "\n") # 曹操妻子，曹昂母亲
print(descriptions['邹氏'] + "\n") # 曹操妾，张绣嫂子
print(descriptions['甘氏'] + "\n") # 刘备妻子，刘婵母亲
print(descriptions['糜氏'] + "\n") # 刘备妾
print(descriptions['孙氏'] + "\n") # 陆逊妻子
print(descriptions['蔡氏'] + "\n") # 刘表妻子
# Out:
# 卞姓，姓氏的一种。在宋版《百家姓》中排名第86位。卞氏是一个多民族、多源流的姓氏群体，在当今姓氏排行榜上名列第243位，人口约三十八万一千余，占全国人口总数的0.024%左右。卞姓源于姬姓，出自黄帝裔孙吾融之后，属于以国名为氏。...
#
# 暂时没有公开的信息
#
# 邹姓，中华姓氏之一，在当今中国姓氏中排名第六十位，源流很多，有一支源于姚姓，姚姓之邹：舜帝姚姓。舜擅长占卜预测，亦称姚舜。舜帝后裔姚姓族人开创建有邹国，是最早的邹国，是商朝的诸侯国，姓名名典《姓觽》：“邹国，舜后，姚姓“。西周初有一支源于子姓，到春秋时期的正考父，他的子孙食于邹邑，是为主要来源，是“以邑为邹氏”。...
#
# 甘姓在宋版《百家姓》居第245位，现行较常见姓氏。分布很广，遍及祖国南北。今安徽太湖、上海嘉定、江西丰城、莲花县、湘东区、芦溪县、南丰县、金溪、崇仁、高安、南昌，广西玉林、梧州、贵港、北海、柳州、平南、百色，湖北浠水、麻城、红安、峨边，四川合江、邻水，贵州遵义、毕节、兴义，湖南汨罗和湖南湘阴月湾村、常德、衡阳祁东县，福建仙游，广东新兴、紫金、五华 ，云南陇川、河口，河南南召、光山甚至北京，河北景县，河北南宫市甘狼冢村，河北藁城西马村，山东平邑、龙口，内蒙古乌海，温州洞头，东北吉林，山西太原等地均有分布，其中湖北省十堰市竹溪县甘家岭村最为集中。汉族、壮族、傣族、彝族、土族、侗族、土家族、布依族、满族等多个民族有此姓。《郑通志·氏族略》收载。...
#
# 糜姓起源于夏代，是以职业和所从事的对象为姓的姓氏。夏代有同姓诸侯，专门种植豆黍之类的农作物，其中有“糜子”，为主要作物。种植这种作物，在当时是很先进的生产活动，因为每年有可靠的收成，因此，种糜的族人富裕而昌盛，后人不以职业为姓，世代姓糜，称糜氏。《百家姓考略》称：“糜，夏同姓诸侯有糜氏之后。”又，商周之际有靡（糜）国，国人以糜为姓。见《周书》。...
#
# ...

# %% [markdown]
# 果然这些情报都有问题，可以通过人工更改信息。

# %%
correct_urls = {}
correct_urls['卞氏'] = "https://baike.baidu.com/item/%E6%AD%A6%E5%AE%A3%E5%8D%9E%E7%9A%87%E5%90%8E"
correct_urls['刘氏'] = "https://baike.baidu.com/item/%E5%88%98%E5%A4%AB%E4%BA%BA/9659436"
correct_urls['邹氏'] = "https://baike.baidu.com/item/%E9%82%B9%E5%A4%AB%E4%BA%BA/18168"
correct_urls['甘氏'] = "https://baike.baidu.com/item/%E7%94%98%E5%A4%AB%E4%BA%BA/16927"
correct_urls['糜氏'] = "https://baike.baidu.com/item/%E9%BA%8B%E5%A4%AB%E4%BA%BA/8576154"
correct_urls['孙氏'] = "https://baike.baidu.com/item/%E9%99%86%E5%AD%99%E6%B0%8F/22471611"
correct_urls['蔡氏'] = "https://baike.baidu.com/item/%E8%94%A1%E5%A4%AB%E4%BA%BA/9508399"
correct_urls['庞德公'] = "https://baike.baidu.com/item/%E5%BA%9E%E5%BE%B7%E5%85%AC/1693895"
correct_urls['黄祖'] = "https://baike.baidu.com/item/%E9%BB%84%E7%A5%96/17037"

# %%
for name, url in correct_urls.items():
    print('Now is %s' % name)
    html = requests.get(url, headers=headers).content.decode('utf8')
    soup = BeautifulSoup(html,'lxml')
    
    # 人物简介
    metatag = soup.find("meta", {"name": "description"})
    if metatag:
        descriptions[name] = metatag['content']
    else: # 如果不存在
        descriptions[name] = "暂时没有公开的信息"
        print('%s has no descriptions' % name)
    
    # 图片
    summary = soup.find("div", {"class": "summary-pic"})
    if summary: # 如果存在summary-pic再保存图片
        link = summary.img['src']
        pic = requests.get(link)
        f = open(path + name + '.jpg', 'wb')
        f.write(pic.content)
        f.close()
        print('Save image')
    else:
        print('%s has no picture' % name)
# Out:
# Now is 卞氏
# Save image
# Now is 刘氏
# Save image
# Now is 邹氏
# Save image
# Now is 甘氏
# Save image
# Now is 糜氏
# Save image
# Now is 孙氏
# Save image
# Now is 蔡氏
# Save image
# Now is 庞德公
# Save image
# Now is 黄祖
# Save image

# %%
print(len(descriptions))
print(descriptions['卞氏'] + "\n") # 曹操妻子，曹丕母亲
print(descriptions['刘氏'] + "\n") # 曹操妻子，曹昂母亲
print(descriptions['邹氏'] + "\n") # 曹操妾，张绣嫂子
print(descriptions['甘氏'] + "\n") # 刘备妻子，刘婵母亲
print(descriptions['糜氏'] + "\n") # 刘备妾
print(descriptions['孙氏'] + "\n") # 陆逊妻子
print(descriptions['蔡氏'] + "\n") # 刘表妻子
# Out:
# 122
# 武宣皇后卞氏（159年12月30日－230年7月9日），琅邪开阳（今山东临沂）人，魏武帝曹操的正妻（继室），魏文帝曹丕、任城威王曹彰、陈思王曹植、萧怀王曹熊的母亲。原本是倡家，即汉代专门从事音乐歌舞的乐人家庭，后来与曹操成婚，建安初年，原配丁夫人被废，卞夫人成为曹操的正妻。曹丕继位后尊其为皇太后，曹叡继位后尊其为太皇太后。卞后在太和四年去世，与魏武帝曹操合葬高陵。...
#
# 刘氏（刘夫人）：曹操的妻妾，生有曹昂、曹铄和清河长公主。不久刘夫人病亡，长子曹昂由正室丁夫人抚养。...
#
# 《三国志》记载中，东汉末年张济之妻，张绣之婶，未言其姓名。《三国演义》里姓邹，故常称作邹氏，或邹夫人。出现在第十六回，被曹操强纳，因而之后有张绣造反，曹操兵败宛城，曹昂、典韦、曹安民战死等诸多之事。...
#
# 甘夫人（177年－？），《夔州府志》作名甘梅，生卒年不详，沛国人，三国时期蜀汉昭烈帝刘备之妾，蜀汉后主刘禅的生母。刘备因早年多次丧偶，甘夫人常代理主持家事。甘夫人随刘备到荆州时，生刘禅，后来去世，葬于南郡。刘备称帝后，追谥亡妾甘氏为“皇思夫人”。刘禅即位后追谥生母甘夫人为“昭烈皇后”。（概述内图片来源：《中国后妃百图》）...
#
# 麋夫人，生卒年不详，东海郡朐县（江苏连云港西南）人，三国时蜀汉大臣麋竺的妹妹。196年－200年间为刘备夫人，衣带诏事发后与关羽一起被曹操俘虏，此后事迹不详。...
#
# 孙夫人（生卒年不详），孙策之女，由孙权许配给陆逊为妻，生一子陆抗。名字，称呼均不详。...
#
# 蔡夫人，东汉末年荆州牧刘表的后妻，襄阳（今湖北襄阳）人，荆襄一带的豪族蔡氏家族的一员。她是诸葛亮之妻黄月英的姨母，以侄女妻表次子刘琮，因爱之，常毁刘琦而誉刘琮于表。表死，与蔡瑁等共排表长子刘琦，奉刘琮为嗣，寻降曹操。...

# %% [markdown]
# 这下子所有人物都有正确的简介了，图片的话122人中，只有**曹嵩**没有图片。在互动百科中找到曹嵩的图片，人工添加
#
# 下面保存人物介绍到JSON格式的文件中。设置`ensure_ascii=False`，就能正常看到中文了。

# %%
with open('data.json', 'w') as f:
    json.dump(descriptions, f, ensure_ascii=False)

# %%
with open('data.json', 'r') as f:
    data = json.load(f)
